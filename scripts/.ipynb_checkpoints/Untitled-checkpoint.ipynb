# %%
# !pip install --upgrade jupyter ipywidgets
jupyter nbextension enable --py widgetsnbextension
# Out:
#   Cell In[11], line 2
#     jupyter nbextension enable --py widgetsnbextension
#             ^
# SyntaxError: invalid syntax

# %%
import kagglehub
import json


with open("C:/Users/saksh/.kaggle/kaggle.json") as f:
    print(json.load(f))
handle = "vishnug05/training-dataset"

# Use folder (NOT zip)
local_dataset_dir = 'C:/Users/saksh/Desktop/CodeWizard-2.0/training'

print("Uploading started...")

kagglehub.dataset_upload(
    handle,
    local_dataset_dir,
    version_notes="first upload"
)

print("Upload completed!")
# Out:
# {'username': 'vishnug05', 'key': 'b30c5b593946ab6a0d814eb50ec3acdf'}
# Uploading started...
# Uploading Dataset https://kaggle.com/datasets/vishnug05/training-dataset ...
# ---------------------------------------------------------------------------
# BackendError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets_helpers.py:58, in create_dataset_or_version(dataset_handle, files, version_notes)
#      57 try:
# ---> 58     _create_dataset(dataset_handle, files)
#      59 except BackendError as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets_helpers.py:30, in _create_dataset(dataset_handle, upload_dir)
#      29 r.is_private = True
# ---> 30 handle_mutate_call(lambda: api_client.datasets.dataset_api_client.create_dataset(r))
#      32 logger.info(f"Your dataset has been created.\nFiles are being processed...\nSee at: {dataset_handle.to_url()}")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\exceptions.py:145, in handle_mutate_call(fn)
#     144     error_code = int(response["errorCode"]) if "errorCode" in response else None
# --> 145     raise BackendError(response["error"], error_code)
#     146 return response
#
# BackendError: Please upload at least one file
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[18], line 14
#      10 local_dataset_dir = 'C:/Users/saksh/Desktop/CodeWizard-2.0\training'
#      12 print("Uploading started...")
# ---> 14 kagglehub.dataset_upload(
#      15     handle,
#      16     local_dataset_dir,
#      17     version_notes="first upload"
#      18 )
#      20 print("Upload completed!")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets.py:92, in dataset_upload(handle, local_dataset_dir, version_notes, ignore_patterns)
#      84     raise ValueError(is_versioned_exception)
#      86 tokens = upload_files_and_directories(
#      87     local_dataset_dir,
#      88     item_type=ApiBlobType.DATASET,
#      89     ignore_patterns=normalize_patterns(default=DEFAULT_IGNORE_PATTERNS, additional=ignore_patterns),
#      90 )
# ---> 92 create_dataset_or_version(h, tokens, version_notes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets_helpers.py:62, in create_dataset_or_version(dataset_handle, files, version_notes)
#      59 except BackendError as e:
#      60     if e.error_code in (None, HTTPStatus.CONFLICT):
#      61         # Dataset already exists, creating a new version instead.
# ---> 62         _create_dataset_version(dataset_handle, files, version_notes)
#      63     else:
#      64         raise (e)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets_helpers.py:48, in _create_dataset_version(dataset_handle, upload_dir, version_notes)
#      46 r.body.files = upload_proto.files
#      47 r.body.directories = upload_proto.directories
# ---> 48 handle_mutate_call(lambda: api_client.datasets.dataset_api_client.create_dataset_version(r))
#      49 logger.info(
#      50     f"Your dataset version has been created.\nFiles are being processed...\nSee at: {dataset_handle.to_url()}"
#      51 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\exceptions.py:139, in handle_mutate_call(fn)
#     133 def handle_mutate_call(fn: Callable[[], R]) -> R:
#     134     """
#     135     Handle errors for handlers returning 200 status code & an error message in the body on failure.
#     136
#     137     These are mostly create & update handlers. E.g.: https://github.com/Kaggle/kaggleazure/blob/be355335448271845fc460a6e153f2cd4b030fec/Kaggle.Services.Models/Handlers/ModelApiService/V1/DeleteModelHandler.cs#L29-L31
#     138     """
# --> 139     response = fn().to_dict()
#     140     if not (200 <= response.get("code", 200) < 300):  # noqa: PLR2004
#     141         error_message = response.get("message", "No error message provided")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglehub\datasets_helpers.py:48, in _create_dataset_version.<locals>.<lambda>()
#      46 r.body.files = upload_proto.files
#      47 r.body.directories = upload_proto.directories
# ---> 48 handle_mutate_call(lambda: api_client.datasets.dataset_api_client.create_dataset_version(r))
#      49 logger.info(
#      50     f"Your dataset version has been created.\nFiles are being processed...\nSee at: {dataset_handle.to_url()}"
#      51 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglesdk\datasets\services\dataset_api_service.py:121, in DatasetApiClient.create_dataset_version(self, request)
#     118 if request is None:
#     119   request = ApiCreateDatasetVersionRequest()
# --> 121 return self._client.call("datasets.DatasetApiService", "CreateDatasetVersion", request, ApiCreateDatasetResponse)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglesdk\kaggle_http_client.py:98, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#      94     settings["stream"] = True
#      96 http_response = self._session.send(http_request, **settings)
# ---> 98 response = self._prepare_response(response_type, http_response)
#      99 return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\kagglesdk\kaggle_http_client.py:124, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     122 except KeyError:
#     123     pass
# --> 124 http_response.raise_for_status()
#     125 # Allow client to check header content.
#     126 if self._response_processor:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:1028, in Response.raise_for_status(self)
#    1023     http_error_msg = (
#    1024         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1025     )
#    1027 if http_error_msg:
# -> 1028     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/CreateDatasetVersion
