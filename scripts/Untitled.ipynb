# %%
# !pip install --upgrade jupyter ipywidgets
jupyter nbextension enable --py widgetsnbextension
# Out:
#   Cell In[11], line 2
#     jupyter nbextension enable --py widgetsnbextension
#             ^
# SyntaxError: invalid syntax

# %%
import kagglehub
import json


with open("C:/Users/saksh/.kaggle/kaggle.json") as f:
    print(json.load(f))
handle = "vishnug05/training-dataset"

# Use folder (NOT zip)
local_dataset_dir = 'C:/Users/saksh/Desktop/CodeWizard-2.0/training'

print("Uploading started...")

kagglehub.dataset_upload(
    handle,
    local_dataset_dir,
    version_notes="first upload"
)

print("Upload completed!")
# Out:
# {'username': 'vishnug05', 'key': 'b30c5b593946ab6a0d814eb50ec3acdf'}
# Uploading started...
# Uploading Dataset https://kaggle.com/datasets/vishnug05/training-dataset ...
# More than 50 files detected, creating a zip archive...
# Starting upload for file C:\Users\saksh\AppData\Local\Temp\tmpnsk_ofsm\archive.zip
# Uploading:   1%|▊                                                                 | 34.3M/2.80G [00:09<09:42, 4.74MB/s]
# Network issue: HTTPSConnectionPool(host='www.googleapis.com', port=443): Max retries exceeded with url: /upload/storage/v1/b/kaggle-data-sets/o?uploadType=resumable&upload_id=AAVLpEiuZCd6-KZ84KW9b8CuDMmorzASlrZcspkt9FSoK2Jjyuk3SwfqQqSgiE6XAAdZQ8yxUnx46JKqTF_-PwQHmiWny7s2mUtTqGxycFgjvhY (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2427)'))), retrying in 1 seconds...
# Uploading:   2%|█▌                                                               | 68.5M/2.80G [07:08<4:17:05, 177kB/s]
# ...
